# %%
import matplotlib.pyplot as plt
from PIL import Image
import urllib.request as url

# %% [markdown]
# #              <font color='red'>  Decision Tree </font>
#
# <div class="">
# <div>
#
#
# The core algorithm for building decision trees called ID3 by <b> J. R. Quinlan</b> which employs a top-down, greedy search through the space of possible branches with no backtracking. The ID3 algorithm can be used to construct a decision tree for<b> regression by replacing Information Gain with Standard Deviation Reduction</b>.

# %%
data=Image.open(r"C:\Users\DELL\Downloads\Decision_tree_r1.png")

# %%
plt.figure(figsize=(15,15))
plt.imshow(data)
plt.axis('off')
# Out:
# (-0.5, 712.5, 257.5, -0.5)

# %% [markdown]
# # <font color='blue'>  Standard Deviation </font>
# A decision tree is built top-down from a root node and involves partitioning the data into subsets that contain instances with similar values (<b>homogenous</b>). We use standard deviation to calculate the homogeneity of a numerical sample. If the numerical sample is completely homogeneous its standard deviation is zero.

# %%
for_Target(one_attributte)
# Out:
#  Standard deviation for one attribute:
# (-0.5, 774.5, 293.5, -0.5)

# %% [markdown]
# #### Average : 39.8
# #### Standard deviation : 9.32
# #### Coefficient of Variation : 23%

# %% [markdown]
# <div class="alert-info">
# <div>
# The dataset is divided based on the values of the selected attribute. This process is run recursively on the non-leaf branches, until all data is processed.
# Here I selected <font color='red'><b>OUTLOOK</b>  </font>. Just because we already know while working on classification 😁 and  to understand easily.How reggression work on

# %% [markdown]
# AS an example:
#
# lets see the example for <font color='red'> OUTLOOK </font>

# %% [markdown]
# <font color="green"> <b> DECISION TREE</b> </font> for  <font color="red">  <b>OUTLOOK</b></font>  looks like
# As shown below ⬇️..

# %%
outlook
# Out:
# (-0.5, 541.5, 286.5, -0.5)

# %% [markdown]
# #### <font color='blue'>  Standard Deviation </font>	for two attributes (target and predictor):

# %%
Standard Deviation  for OUTLOOK
# Out:
# (-0.5, 510.5, 377.5, -0.5)

# %% [markdown]
# # <font color='red'> Standard Deviation Reduction (SDR) </font>
#
# The standard deviation reduction is based on the decrease in standard deviation after a dataset is split on an attribute. Constructing a decision tree is all about finding attribute that returns the highest standard deviation reduction (i.e., the most homogeneous branches).

# %% [markdown]
# <font color='chocolate'><b>step:- 1</b>  </font>
# The standard deviation of the target is calculated.
#
# <font color='blue'>  Standard Deviation </font>(Hours Played) = 9.32
#
# <font color='chocolate'><b>step:- 2</b></font> The dataset is then split on the different attributes. The standard deviation for each branch is calculated. The resulting standard deviation is subtracted from the standard deviation before the split. The result is the standard deviation reduction.

# %%
SDR_FOR_DIFFERENT_ATTRIBUTTES

# %% [markdown]
# ### <font color='chocolate'><b>step:- 3</b></font>
# ###### The attribute with the largest standard deviation reduction is chosen for the decision node.

# %%
SDR_Outlook
# Out:
# (-0.5, 219.5, 168.5, -0.5)

# %% [markdown]
# ### <font color='chocolate'><b>step:- 4a :</b></font>
# ###### The dataset is divided based on the values of the selected attribute. This process is run recursively on the non-leaf branches, until all data is processed.

# %%
for_outlok
# Out:
# (-0.5, 541.5, 286.5, -0.5)

# %% [markdown]
# ### <font color='chocolate'><b>step:- 4b :</b></font>
#
# ###### The dataset is divided based on the values of the selected attribute. This process is run recursively on the non-leaf branches, until all data is processed.

# %%
selcted_attribute
# Out:
# (-0.5, 731.5, 268.5, -0.5)

# %% [markdown]
# ### <font color='chocolate'><b>step:- 4c :</b></font>
#   However, the <b>Sunny</b> branch has an CV (28%) more than the threshold (10%) which needs further splitting. We select <b>Temp</b> as the best best node after <b>Outlook</b> because it has the largest SDR.

# %%
outlook_sunny
# Out:
# (-0.5, 586.5, 325.5, -0.5)

# %% [markdown]
#  Because the number of data points for both branches (FALSE and TRUE) is equal or less than 3 we stop further branching and assign the average of each branch to the related leaf node.

# %%
Sunny_Wind
# Out:
# (-0.5, 601.5, 301.5, -0.5)

# %% [markdown]
# <b>step:- 4d</b>: Moreover, the "rainy" branch has an CV (22%) which is more than the threshold (10%). This branch needs further splitting. We select "Temp" as the best best node because it has the largest SDR.

# %%
outlook_rainy
# Out:
# (-0.5, 584.5, 334.5, -0.5)

# %% [markdown]
# Because the number of data points for all three branches (Cool, Hot and Mild) is equal or less than 3 we stop further branching and assign the average of each branch to the related leaf node.

# %%
Final_Regression
# Out:
# (-0.5, 523.5, 244.5, -0.5)

# %% [markdown]
# # <font color='green'>CONCLUSION</font>
#
#
# <font color='navy'><b>
# When the number of instances is more than one at a leaf node we calculate the average as the final value for the target.</b></font>

# %% [markdown]
# ###  For any doubt open the below⬇️👇😁😁 link

# %%
from IPython.core.display import display,HTML
display(HTML("""<a href='https://www.saedsayad.com/decision_tree_reg.htm'>link to gogle document</a>"""))
# Out:
# <a href='https://www.saedsayad.com/decision_tree_reg.htm'>link to gogle document</a>

# %%
# %%html
# <a href='https://www.saedsayad.com/decision_tree_reg.htm'>Showing link</a>
# Out:
# <a href='https://www.saedsayad.com/decision_tree_reg.htm'>Showing link</a>
