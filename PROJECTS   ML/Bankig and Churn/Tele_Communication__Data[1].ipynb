# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\DELL\\DATA SCIENCE\\Machine Learning\\churn_dataset.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
df["TotalCharges"]=pd.to_numeric(df["TotalCharges"],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0           Electronic check          29.85         29.85     No
# 1               Mailed check          56.95       1889.50     No
# 2               Mailed check          53.85        108.15    Yes
# 3  Bank transfer (automatic)          42.30       1840.75     No
# 4           Electronic check          70.70        151.65    Yes
#
# [5 rows x 21 columns]

# %%
df=df.dropna()
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df["customerID"]
# Out:
# 0       7590-VHVEG
# 1       5575-GNVDE
# 2       3668-QPYBK
# 3       7795-CFOCW
# 4       9237-HQITU
#            ...
# 7038    6840-RESVB
# 7039    2234-XADUH
# 7040    4801-JZAZL
# 7041    8361-LTMKD
# 7042    3186-AJIEK
# Name: customerID, Length: 7032, dtype: object

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.1.2

# %%
y=df["Churn"]
X= df[['customerID','gender','Partner','Dependents','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod','SeniorCitizen','tenure','MonthlyCharges','TotalCharges']]

# %%
X.shape
# Out:
# (7032, 20)

# %%
from sklearn.model_selection import  train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.7,random_state=123)

# %%
print(X_train.shape, y_train.shape)

print(X_test.shape, y_test.shape)
# Out:
# (4922, 20) (4922,)
# (2110, 20) (2110,)

# %%
X_train.head()
# Out:
#       customerID  gender Partner Dependents PhoneService MultipleLines  \
# 463   3811-VBYBZ    Male      No         No          Yes           Yes
# 5826  9507-EXLTT  Female     Yes         No          Yes            No
# 1437  1666-JZPZT    Male      No         No          Yes           Yes
# 2890  1732-VHUBQ  Female     Yes        Yes          Yes            No
# 3913  8749-TZYEC    Male     Yes         No          Yes           Yes
#
#      InternetService       OnlineSecurity         OnlineBackup  \
# 463      Fiber optic                   No                  Yes
# 5826     Fiber optic                   No                   No
# 1437             DSL                   No                   No
# 2890     Fiber optic                   No                   No
# 3913              No  No internet service  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 463                    No                   No                  Yes
# 5826                   No                   No                  Yes
# 1437                   No                   No                   No
# 2890                   No                   No                   No
# 3913  No internet service  No internet service  No internet service
#
#           StreamingMovies        Contract PaperlessBilling  \
# 463                   Yes  Month-to-month              Yes
# 5826                   No  Month-to-month              Yes
# 1437                   No  Month-to-month               No
# 2890                   No  Month-to-month               No
# 3913  No internet service        Two year               No
#
#                   PaymentMethod  SeniorCitizen  tenure  MonthlyCharges  \
# 463            Electronic check              0       7           99.80
# 5826  Bank transfer (automatic)              0       1           79.35
# 1437               Mailed check              0      27           49.00
# 2890  Bank transfer (automatic)              1      47           70.55
# 3913    Credit card (automatic)              0      72           24.80
#
#       TotalCharges
# 463         673.25
# 5826         79.35
# 1437       1291.35
# 2890       3309.25
# 3913       1874.30

# %%
X_train.dtypes
# Out:
# customerID           object
# gender               object
# Partner              object
# Dependents           object
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# SeniorCitizen         int64
# tenure                int64
# MonthlyCharges      float64
# TotalCharges        float64
# dtype: object

# %%
X_train_cat = X_train.select_dtypes(include=['object'])

X_train_cat.head()
# Out:
#       customerID  gender Partner Dependents PhoneService MultipleLines  \
# 463   3811-VBYBZ    Male      No         No          Yes           Yes
# 5826  9507-EXLTT  Female     Yes         No          Yes            No
# 1437  1666-JZPZT    Male      No         No          Yes           Yes
# 2890  1732-VHUBQ  Female     Yes        Yes          Yes            No
# 3913  8749-TZYEC    Male     Yes         No          Yes           Yes
#
#      InternetService       OnlineSecurity         OnlineBackup  \
# 463      Fiber optic                   No                  Yes
# 5826     Fiber optic                   No                   No
# 1437             DSL                   No                   No
# 2890     Fiber optic                   No                   No
# 3913              No  No internet service  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 463                    No                   No                  Yes
# 5826                   No                   No                  Yes
# 1437                   No                   No                   No
# 2890                   No                   No                   No
# 3913  No internet service  No internet service  No internet service
#
#           StreamingMovies        Contract PaperlessBilling  \
# 463                   Yes  Month-to-month              Yes
# 5826                   No  Month-to-month              Yes
# 1437                   No  Month-to-month               No
# 2890                   No  Month-to-month               No
# 3913  No internet service        Two year               No
#
#                   PaymentMethod
# 463            Electronic check
# 5826  Bank transfer (automatic)
# 1437               Mailed check
# 2890  Bank transfer (automatic)
# 3913    Credit card (automatic)

# %%
X_train_num = X_train.select_dtypes(include=['int64', 'float64'])

X_train_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 463               0       7           99.80        673.25
# 5826              0       1           79.35         79.35
# 1437              0      27           49.00       1291.35
# 2890              1      47           70.55       3309.25
# 3913              0      72           24.80       1874.30

# %%
# X_train_num.head()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# column names are (annoyingly) lost after Scaling
# (i.e. the dataframe is converted to a numpy ndarray)

X_train_num_rescaled = pd.DataFrame(scaler.fit_transform(X_train_num), 
                                    columns = X_train_num.columns, 
                                    index = X_train_num.index)

X_train_num_rescaled.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# 463       -0.433622 -1.045440        1.166162     -0.717660
# 5826      -0.433622 -1.289959        0.485349     -0.978977
# 1437      -0.433622 -0.230377       -0.525051     -0.445696
# 2890       2.306156  0.584686        0.192383      0.442181
# 3913      -0.433622  1.603514       -1.330708     -0.189198

# %%
cust_id=pd.DataFrame(X_train_cat["customerID"])
cust_id
# Out:
#       customerID
# 463   3811-VBYBZ
# 5826  9507-EXLTT
# 1437  1666-JZPZT
# 2890  1732-VHUBQ
# 3913  8749-TZYEC
# ...          ...
# 5227  4060-LDNLU
# 4067  9140-CZQZZ
# 1351  7266-GSSJX
# 3460  2669-OIDSD
# 3588  9643-YBLUR
#
# [4922 rows x 1 columns]

# %%
del(X_train_cat["customerID"])
X_train_cat.head()
# Out:
#       gender Partner Dependents PhoneService MultipleLines InternetService  \
# 463     Male      No         No          Yes           Yes     Fiber optic
# 5826  Female     Yes         No          Yes            No     Fiber optic
# 1437    Male      No         No          Yes           Yes             DSL
# 2890  Female     Yes        Yes          Yes            No     Fiber optic
# 3913    Male     Yes         No          Yes           Yes              No
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 463                    No                  Yes                   No
# 5826                   No                   No                   No
# 1437                   No                   No                   No
# 2890                   No                   No                   No
# 3913  No internet service  No internet service  No internet service
#
#               TechSupport          StreamingTV      StreamingMovies  \
# 463                    No                  Yes                  Yes
# 5826                   No                  Yes                   No
# 1437                   No                   No                   No
# 2890                   No                   No                   No
# 3913  No internet service  No internet service  No internet service
#
#             Contract PaperlessBilling              PaymentMethod
# 463   Month-to-month              Yes           Electronic check
# 5826  Month-to-month              Yes  Bank transfer (automatic)
# 1437  Month-to-month               No               Mailed check
# 2890  Month-to-month               No  Bank transfer (automatic)
# 3913        Two year               No    Credit card (automatic)

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', sparse=False)

# column names are (annoyingly) lost after OneHotEncoding
# (i.e. the dataframe is converted to a numpy ndarray)

X_train_cat_ohe = pd.DataFrame(encoder.fit_transform(X_train_cat), 
                               columns=encoder.get_feature_names_out(X_train_cat.columns), 
                               index = X_train_cat.index)

X_train_cat_ohe.head()
# Out:
#       gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 463           1.0          0.0             0.0               1.0
# 5826          0.0          1.0             0.0               1.0
# 1437          1.0          0.0             0.0               1.0
# 2890          0.0          1.0             1.0               1.0
# 3913          1.0          1.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 463                              0.0                1.0
# 5826                             0.0                0.0
# 1437                             0.0                1.0
# 2890                             0.0                0.0
# 3913                             0.0                1.0
#
#       InternetService_Fiber optic  InternetService_No  \
# 463                           1.0                 0.0
# 5826                          1.0                 0.0
# 1437                          0.0                 0.0
# 2890                          1.0                 0.0
# 3913                          0.0                 1.0
#
#       OnlineSecurity_No internet service  OnlineSecurity_Yes  ...  \
# 463                                  0.0                 0.0  ...
# 5826                                 0.0                 0.0  ...
# 1437                                 0.0                 0.0  ...
# 2890                                 0.0                 0.0  ...
# 3913                                 1.0                 0.0  ...
#
#       StreamingTV_No internet service  StreamingTV_Yes  \
# 463                               0.0              1.0
# 5826                              0.0              1.0
# 1437                              0.0              0.0
# 2890                              0.0              0.0
# 3913                              1.0              0.0
#
#       StreamingMovies_No internet service  StreamingMovies_Yes  \
# 463                                   0.0                  1.0
# 5826                                  0.0                  0.0
# 1437                                  0.0                  0.0
# 2890                                  0.0                  0.0
# 3913                                  1.0                  0.0
#
#       Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 463                 0.0                0.0                   1.0
# 5826                0.0                0.0                   1.0
# 1437                0.0                0.0                   0.0
# 2890                0.0                0.0                   0.0
# 3913                0.0                1.0                   0.0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 463                                     0.0                             1.0
# 5826                                    0.0                             0.0
# 1437                                    0.0                             0.0
# 2890                                    0.0                             0.0
# 3913                                    1.0                             0.0
#
#       PaymentMethod_Mailed check
# 463                          0.0
# 5826                         0.0
# 1437                         1.0
# 2890                         0.0
# 3913                         0.0
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Concatinating the Encoded Categorical Features and Rescaled Numerical Features

# %%
X_train_transformed = pd.concat([X_train_num_rescaled, X_train_cat_ohe], axis=1)

X_train_transformed.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 463       -0.433622 -1.045440        1.166162     -0.717660          1.0
# 5826      -0.433622 -1.289959        0.485349     -0.978977          0.0
# 1437      -0.433622 -0.230377       -0.525051     -0.445696          1.0
# 2890       2.306156  0.584686        0.192383      0.442181          0.0
# 3913      -0.433622  1.603514       -1.330708     -0.189198          1.0
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 463           0.0             0.0               1.0
# 5826          1.0             0.0               1.0
# 1437          0.0             0.0               1.0
# 2890          1.0             1.0               1.0
# 3913          1.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 463                              0.0                1.0  ...
# 5826                             0.0                0.0  ...
# 1437                             0.0                1.0  ...
# 2890                             0.0                0.0  ...
# 3913                             0.0                1.0  ...
#
#       StreamingTV_No internet service  StreamingTV_Yes  \
# 463                               0.0              1.0
# 5826                              0.0              1.0
# 1437                              0.0              0.0
# 2890                              0.0              0.0
# 3913                              1.0              0.0
#
#       StreamingMovies_No internet service  StreamingMovies_Yes  \
# 463                                   0.0                  1.0
# 5826                                  0.0                  0.0
# 1437                                  0.0                  0.0
# 2890                                  0.0                  0.0
# 3913                                  1.0                  0.0
#
#       Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 463                 0.0                0.0                   1.0
# 5826                0.0                0.0                   1.0
# 1437                0.0                0.0                   0.0
# 2890                0.0                0.0                   0.0
# 3913                0.0                1.0                   0.0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 463                                     0.0                             1.0
# 5826                                    0.0                             0.0
# 1437                                    0.0                             0.0
# 2890                                    0.0                             0.0
# 3913                                    1.0                             0.0
#
#       PaymentMethod_Mailed check
# 463                          0.0
# 5826                         0.0
# 1437                         1.0
# 2890                         0.0
# 3913                         0.0
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Test Data

# %%
X_test.head()
# Out:
#       customerID  gender Partner Dependents PhoneService     MultipleLines  \
# 6830  7815-PDTHL    Male      No         No          Yes                No
# 364   3583-KRKMD    Male      No         No          Yes                No
# 2067  4832-VRBMR    Male     Yes         No          Yes               Yes
# 6964  1264-FUHCX  Female     Yes         No           No  No phone service
# 4868  2568-OIADY  Female     Yes         No          Yes               Yes
#
#      InternetService       OnlineSecurity         OnlineBackup  \
# 6830              No  No internet service  No internet service
# 364      Fiber optic                   No                   No
# 2067     Fiber optic                   No                  Yes
# 6964             DSL                   No                  Yes
# 4868     Fiber optic                   No                   No
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 6830  No internet service  No internet service  No internet service
# 364                    No                  Yes                   No
# 2067                  Yes                   No                  Yes
# 6964                   No                  Yes                  Yes
# 4868                  Yes                   No                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 6830  No internet service        Two year              Yes
# 364                    No  Month-to-month              Yes
# 2067                  Yes        One year              Yes
# 6964                  Yes        One year              Yes
# 4868                  Yes  Month-to-month              Yes
#
#                   PaymentMethod  SeniorCitizen  tenure  MonthlyCharges  \
# 6830               Mailed check              0      35           20.20
# 364   Bank transfer (automatic)              0      18           75.90
# 2067  Bank transfer (automatic)              1      65          103.15
# 6964    Credit card (automatic)              0      49           56.30
# 4868           Electronic check              0      37           99.50
#
#       TotalCharges
# 6830        684.40
# 364        1373.05
# 2067       6792.45
# 6964       2780.60
# 4868       3762.00

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2110 entries, 6830 to 3851
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        2110 non-null   object
#  1   gender            2110 non-null   object
#  2   Partner           2110 non-null   object
#  3   Dependents        2110 non-null   object
#  4   PhoneService      2110 non-null   object
#  5   MultipleLines     2110 non-null   object
#  6   InternetService   2110 non-null   object
#  7   OnlineSecurity    2110 non-null   object
#  8   OnlineBackup      2110 non-null   object
#  9   DeviceProtection  2110 non-null   object
#  10  TechSupport       2110 non-null   object
#  11  StreamingTV       2110 non-null   object
#  12  StreamingMovies   2110 non-null   object
#  13  Contract          2110 non-null   object
#  14  PaperlessBilling  2110 non-null   object
#  15  PaymentMethod     2110 non-null   object
#  16  SeniorCitizen     2110 non-null   int64
#  17  tenure            2110 non-null   int64
#  18  MonthlyCharges    2110 non-null   float64
#  19  TotalCharges      2110 non-null   float64
# dtypes: float64(2), int64(2), object(16)
# memory usage: 346.2+ KB

# %%
X_test_num=X_test.select_dtypes(include=['int',"float"])
X_test_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 6830              0      35           20.20        684.40
# 364               0      18           75.90       1373.05
# 2067              1      65          103.15       6792.45
# 6964              0      49           56.30       2780.60
# 4868              0      37           99.50       3762.00

# %%
X_test_cat=X_test.select_dtypes(include=['object'])
X_test_cat.head()
# Out:
#       customerID  gender Partner Dependents PhoneService     MultipleLines  \
# 6830  7815-PDTHL    Male      No         No          Yes                No
# 364   3583-KRKMD    Male      No         No          Yes                No
# 2067  4832-VRBMR    Male     Yes         No          Yes               Yes
# 6964  1264-FUHCX  Female     Yes         No           No  No phone service
# 4868  2568-OIADY  Female     Yes         No          Yes               Yes
#
#      InternetService       OnlineSecurity         OnlineBackup  \
# 6830              No  No internet service  No internet service
# 364      Fiber optic                   No                   No
# 2067     Fiber optic                   No                  Yes
# 6964             DSL                   No                  Yes
# 4868     Fiber optic                   No                   No
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 6830  No internet service  No internet service  No internet service
# 364                    No                  Yes                   No
# 2067                  Yes                   No                  Yes
# 6964                   No                  Yes                  Yes
# 4868                  Yes                   No                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 6830  No internet service        Two year              Yes
# 364                    No  Month-to-month              Yes
# 2067                  Yes        One year              Yes
# 6964                  Yes        One year              Yes
# 4868                  Yes  Month-to-month              Yes
#
#                   PaymentMethod
# 6830               Mailed check
# 364   Bank transfer (automatic)
# 2067  Bank transfer (automatic)
# 6964    Credit card (automatic)
# 4868           Electronic check

# %%
X_test_num_rescaled = pd.DataFrame(scaler.transform(X_test_num), 
                                   columns = X_test_num.columns, 
                                   index = X_test_num.index)

X_test_num_rescaled.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# 6830      -0.433622  0.095648       -1.483849     -0.712754
# 364       -0.433622 -0.597155        0.370493     -0.409748
# 2067       2.306156  1.318242        1.277689      1.974790
# 6964      -0.433622  0.666192       -0.282023      0.209575
# 4868      -0.433622  0.177154        1.156175      0.641391

# %%
del(X_test_cat["customerID"])
X_test_cat.head()
# Out:
#       gender Partner Dependents PhoneService     MultipleLines  \
# 6830    Male      No         No          Yes                No
# 364     Male      No         No          Yes                No
# 2067    Male     Yes         No          Yes               Yes
# 6964  Female     Yes         No           No  No phone service
# 4868  Female     Yes         No          Yes               Yes
#
#      InternetService       OnlineSecurity         OnlineBackup  \
# 6830              No  No internet service  No internet service
# 364      Fiber optic                   No                   No
# 2067     Fiber optic                   No                  Yes
# 6964             DSL                   No                  Yes
# 4868     Fiber optic                   No                   No
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 6830  No internet service  No internet service  No internet service
# 364                    No                  Yes                   No
# 2067                  Yes                   No                  Yes
# 6964                   No                  Yes                  Yes
# 4868                  Yes                   No                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 6830  No internet service        Two year              Yes
# 364                    No  Month-to-month              Yes
# 2067                  Yes        One year              Yes
# 6964                  Yes        One year              Yes
# 4868                  Yes  Month-to-month              Yes
#
#                   PaymentMethod
# 6830               Mailed check
# 364   Bank transfer (automatic)
# 2067  Bank transfer (automatic)
# 6964    Credit card (automatic)
# 4868           Electronic check

# %%
X_test_cat.shape
# Out:
# (2110, 15)

# %%
# OneHotEncoding the categorical features

from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', sparse=False)

# column names are (annoyingly) lost after OneHotEncoding
# (i.e. the dataframe is converted to a numpy ndarray)

X_test_cat_ohe = pd.DataFrame(encoder.fit_transform(X_test_cat), 
                               columns=encoder.get_feature_names_out(X_test_cat.columns), 
                               index = X_test_cat.index)

X_test_cat_ohe.head()
# Out:
#       gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 6830          1.0          0.0             0.0               1.0
# 364           1.0          0.0             0.0               1.0
# 2067          1.0          1.0             0.0               1.0
# 6964          0.0          1.0             0.0               0.0
# 4868          0.0          1.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 6830                             0.0                0.0
# 364                              0.0                0.0
# 2067                             0.0                1.0
# 6964                             1.0                0.0
# 4868                             0.0                1.0
#
#       InternetService_Fiber optic  InternetService_No  \
# 6830                          0.0                 1.0
# 364                           1.0                 0.0
# 2067                          1.0                 0.0
# 6964                          0.0                 0.0
# 4868                          1.0                 0.0
#
#       OnlineSecurity_No internet service  OnlineSecurity_Yes  ...  \
# 6830                                 1.0                 0.0  ...
# 364                                  0.0                 0.0  ...
# 2067                                 0.0                 0.0  ...
# 6964                                 0.0                 0.0  ...
# 4868                                 0.0                 0.0  ...
#
#       StreamingTV_No internet service  StreamingTV_Yes  \
# 6830                              1.0              0.0
# 364                               0.0              0.0
# 2067                              0.0              1.0
# 6964                              0.0              1.0
# 4868                              0.0              1.0
#
#       StreamingMovies_No internet service  StreamingMovies_Yes  \
# 6830                                  1.0                  0.0
# 364                                   0.0                  0.0
# 2067                                  0.0                  1.0
# 6964                                  0.0                  1.0
# 4868                                  0.0                  1.0
#
#       Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 6830                0.0                1.0                   1.0
# 364                 0.0                0.0                   1.0
# 2067                1.0                0.0                   1.0
# 6964                1.0                0.0                   1.0
# 4868                0.0                0.0                   1.0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 6830                                    0.0                             0.0
# 364                                     0.0                             0.0
# 2067                                    0.0                             0.0
# 6964                                    1.0                             0.0
# 4868                                    0.0                             1.0
#
#       PaymentMethod_Mailed check
# 6830                         1.0
# 364                          0.0
# 2067                         0.0
# 6964                         0.0
# 4868                         0.0
#
# [5 rows x 26 columns]

# %%
X_test_transformed = pd.concat([X_test_num_rescaled, X_test_cat_ohe], axis=1)

X_test_transformed.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 6830      -0.433622  0.095648       -1.483849     -0.712754          1.0
# 364       -0.433622 -0.597155        0.370493     -0.409748          1.0
# 2067       2.306156  1.318242        1.277689      1.974790          1.0
# 6964      -0.433622  0.666192       -0.282023      0.209575          0.0
# 4868      -0.433622  0.177154        1.156175      0.641391          0.0
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 6830          0.0             0.0               1.0
# 364           0.0             0.0               1.0
# 2067          1.0             0.0               1.0
# 6964          1.0             0.0               0.0
# 4868          1.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 6830                             0.0                0.0  ...
# 364                              0.0                0.0  ...
# 2067                             0.0                1.0  ...
# 6964                             1.0                0.0  ...
# 4868                             0.0                1.0  ...
#
#       StreamingTV_No internet service  StreamingTV_Yes  \
# 6830                              1.0              0.0
# 364                               0.0              0.0
# 2067                              0.0              1.0
# 6964                              0.0              1.0
# 4868                              0.0              1.0
#
#       StreamingMovies_No internet service  StreamingMovies_Yes  \
# 6830                                  1.0                  0.0
# 364                                   0.0                  0.0
# 2067                                  0.0                  1.0
# 6964                                  0.0                  1.0
# 4868                                  0.0                  1.0
#
#       Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 6830                0.0                1.0                   1.0
# 364                 0.0                0.0                   1.0
# 2067                1.0                0.0                   1.0
# 6964                1.0                0.0                   1.0
# 4868                0.0                0.0                   1.0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 6830                                    0.0                             0.0
# 364                                     0.0                             0.0
# 2067                                    0.0                             0.0
# 6964                                    1.0                             0.0
# 4868                                    0.0                             1.0
#
#       PaymentMethod_Mailed check
# 6830                         1.0
# 364                          0.0
# 2067                         0.0
# 6964                         0.0
# 4868                         0.0
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Logistic  Regression

# %%
from sklearn.linear_model import LogisticRegression
regressor = LogisticRegression()
regressor.fit(X_train_transformed, y_train)
# Out:
# LogisticRegression()

# %%
y_test_pred = regressor.predict(X_test_transformed)

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})

temp_df.head()
# Out:
#      Actual Predicted
# 6830     No        No
# 364      No        No
# 2067     No        No
# 6964     No        No
# 4868    Yes       Yes

# %%
import sklearn
linear_accuracy=sklearn.metrics.accuracy_score(y_test, y_test_pred)
linear_accuracy
# Out:
# 0.8075829383886256

# %% [markdown]
# ## KNN Classifiers

# %%
from sklearn.neighbors import KNeighborsClassifier
regressor = KNeighborsClassifier()
regressor.fit(X_train_transformed, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_test_pred = regressor.predict(X_test_transformed)

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})

temp_df.head()
# Out:
#      Actual Predicted
# 6830     No        No
# 364      No        No
# 2067     No        No
# 6964     No        No
# 4868    Yes        No

# %%
from sklearn import metrics
KNN_classifier= metrics.accuracy_score(y_test, y_test_pred)

# %% [markdown]
# ## Decision Tree  Classifiers

# %%
from sklearn.tree import DecisionTreeClassifier
regressor = DecisionTreeClassifier()
regressor.fit(X_train_transformed, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_test_pred = regressor.predict(X_test_transformed)

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})
temp_df.head()
# Out:
#      Actual Predicted
# 6830     No        No
# 364      No        No
# 2067     No        No
# 6964     No        No
# 4868    Yes        No

# %%
from sklearn import metrics
decission_tree=metrics.accuracy_score(y_test, y_test_pred)

# %% [markdown]
# ## Randm Forest Calssifiers

# %%
from sklearn.ensemble import RandomForestClassifier
regressor = RandomForestClassifier()
regressor.fit(X_train_transformed, y_train)
# Out:
# RandomForestClassifier()

# %%
y_test_pred = regressor.predict(X_test_transformed)

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})
temp_df.head()
# Out:
#      Actual Predicted
# 6830     No        No
# 364      No        No
# 2067     No        No
# 6964     No        No
# 4868    Yes        No

# %%
Random_forest= metrics.accuracy_score(y_test, y_test_pred)

# %% [markdown]
# ## Support Vector Machines

# %%
 from sklearn.svm import SVC
regressor =SVC()
regressor.fit(X_train_transformed, y_train)
# Out:
# SVC()

# %%
y_test_pred = regressor.predict(X_test_transformed)

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})
temp_df.head()
# Out:
#      Actual Predicted
# 6830     No        No
# 364      No        No
# 2067     No        No
# 6964     No        No
# 4868    Yes        No

# %%
SVM= metrics.accuracy_score(y_test, y_test_pred)

# %%
algo_accuracy=pd.DataFrame([KNN_classifier,linear_accuracy,SVM,Random_forest,decission_tree],
                          index=["KNN Classifier","Logistic Regression","Support vector","Random forest Classifier","Decision Tree Classifier"],
                          columns=["Accuracy"])

algo_accuracy.sort_values(by='Accuracy',ascending=False,inplace=True)

# %%
algo_accuracy
# Out:
#                           Accuracy
# Logistic Regression       0.807583
# Support vector            0.794313
# Random forest Classifier  0.780095
# KNN Classifier            0.743602
# Decision Tree Classifier  0.707109

# %%
plt.figure(figsize=(15,7))

ax=sns.lineplot(x=algo_accuracy.index,y='Accuracy',data=algo_accuracy)
plt.xticks(rotation=90)

for i,acc in enumerate(algo_accuracy["Accuracy"]):
    plt.annotate(round(acc*100,4),(algo_accuracy.index[i],algo_accuracy["Accuracy"][i]))
    
plt.show()
